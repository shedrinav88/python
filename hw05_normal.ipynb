# %%
# Задача-1:
# Напишите небольшую консольную утилиту,
# позволяющую работать с папками текущей директории.
# Утилита должна иметь меню выбора действия, в котором будут пункты:
# 1. Перейти в папку
# 2. Просмотреть содержимое текущей папки
# 3. Удалить папку
# 4. Создать папку
# При выборе пунктов 1, 3, 4 программа запрашивает название папки
# и выводит результат действия: "Успешно создано/удалено/перешел",
# "Невозможно создать/удалить/перейти"

# Для решения данной задачи используйте алгоритмы из задания easy,
# оформленные в виде соответствующих функций,
# и импортированные в данный файл из easy.py


import os
import Lib.easy as easy

name = input('Как Вас зовут? ')

print('Добрый день, {}.\nЯ Ваш помощник, вот что я могу сделать:\n'
      '[1] Перейти в папку\n[2] Просмотреть содержимое текущей папки\n[3] Создать папку\n'
      '[4] Удалить папку'.format(name))
choose = ''
while choose != 'q':
    choose = input('Введите № действия и я его выполню.\nЕсли хотите прекратить мою работу, введите [q] ')
    if choose == '1':
        easy.open_folder()
    if choose == '2':
        print(easy.show_dir())
    if choose == '3':
        easy.make_dir()
    if choose == '4':
        easy.remove_dir()
    elif choose != '1' and choose != '2' and choose != '3' and choose != '4' and choose != 'q':
        print('Некорректный ввод!')
# Out:
# Как Вас зовут? Андрей
# Добрый день, Андрей.
# Я Ваш помощник, вот что я могу сделать:
# [1] Перейти в папку
# [2] Просмотреть содержимое текущей папки
# [3] Создать папку
# [4] Удалить папку
# Введите № действия и я его выполню.
# Если хотите прекратить мою работу, введите [q] 1
# Напишите название папки, в которую нужно перейти: Вшкусешщт
# Такая директория не найдена! Попробуйте снова зайти в данный пункт меню и ввести полный путь к директории!
# Введите № действия и я его выполню.
# Если хотите прекратить мою работу, введите [q] 1
# Напишите название папки, в которую нужно перейти: Direction
# Перешел в новую директорию: C:\Users\admin\Downloads\Direction
# Введите № действия и я его выполню.
# Если хотите прекратить мою работу, введите [q] 2
# Содержимое текущей директории: ['Abrohamoooo', 'Dhsk', 'Dir 1', 'Dir2', 'Dir4', 'Diroghjk', 'Drovosecoooo', 'Folder', 'Gago']
# None
# Введите № действия и я его выполню.
# Если хотите прекратить мою работу, введите [q] 3
# ...
